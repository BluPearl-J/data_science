# %%
import pandas as pd
import numpy as np

# %%
data={
    'Name':['Alice','Bob','Charlie','David'],
    'Age':[25,30,35,40],
    'gender':['F','M','M','M'],
    'nationality':['USA','UK','USA','UK'],
    'city':['NewYork','Scotland','Michigan','Dublin'],
    'height':['5.7','8','7','8']
}
df=pd.DataFrame(data)
df
# Out:
#       Name  Age gender nationality      city height
# 0    Alice   25      F         USA   NewYork    5.7
# 1      Bob   30      M          UK  Scotland      8
# 2  Charlie   35      M         USA  Michigan      7
# 3    David   40      M          UK    Dublin      8

# %%
df.info
# Out:
# <bound method DataFrame.info of       Name  Age gender nationality
# 0    Alice   25      F         USA
# 1      Bob   30      M          UK
# 2  Charlie   35      M         USA
# 3    David   40      M          UK>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         4 non-null      str
#  1   Age          4 non-null      int64
#  2   gender       4 non-null      str
#  3   nationality  4 non-null      str
# dtypes: int64(1), str(3)
# memory usage: 260.0 bytes

# %%
df.shape
# Out:
# (4, 4)

# %%
df.shape
# Out:
# (4, 5)

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   32.500000
# std     6.454972
# min    25.000000
# 25%    28.750000
# 50%    32.500000
# 75%    36.250000
# max    40.000000

# %%
df.describe().T
# Out:
#      count  mean       std   min    25%   50%    75%   max
# Age    4.0  32.5  6.454972  25.0  28.75  32.5  36.25  40.0

# %%
      df.describr().T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.describr().T
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'describr'

# %%
df.describe().T
# Out:
#      count  mean       std   min    25%   50%    75%   max
# Age    4.0  32.5  6.454972  25.0  28.75  32.5  36.25  40.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         4 non-null      str
#  1   Age          4 non-null      int64
#  2   gender       4 non-null      str
#  3   nationality  4 non-null      str
#  4   city         4 non-null      str
#  5   height       4 non-null      str
# dtypes: int64(1), str(5)
# memory usage: 324.0 bytes

# %% [markdown]
# ddddddddsssssssss

# %%
v=pd.read_csv(C:\Users\DELL\Downloads\archive\housing_price_dataset.csv)
# Out:
#   Cell In[19], line 1
#     v=pd.read_csv(C:\Users\DELL\Downloads\archive\housing_price_dataset.csv)
#                    ^
# SyntaxError: invalid syntax

# %%
v=pd.read_csv("C:\Users\DELL\Downloads\archive\housing_price_dataset.csv")
# Out:
#   Cell In[20], line 1
#     v=pd.read_csv("C:\Users\DELL\Downloads\archive\housing_price_dataset.csv")
#                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
v=pd.read_csv(r'\Users\DELL\Downloads\archive\housing_price_dataset.csv')
v
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %%
v.info
# Out:
# <bound method DataFrame.info of        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# ...

# %%
v.describe().T
# Out:
#               count           mean           std           min            25%  \
# SquareFeet  50000.0    2006.374680    575.513241   1000.000000    1513.000000
# Bedrooms    50000.0       3.498700      1.116326      2.000000       3.000000
# Bathrooms   50000.0       1.995420      0.815851      1.000000       1.000000
# YearBuilt   50000.0    1985.404420     20.719377   1950.000000    1967.000000
# Price       50000.0  224827.325151  76141.842966 -36588.165397  169955.860225
#
#                       50%            75%            max
# SquareFeet    2007.000000    2506.000000    2999.000000
# Bedrooms         3.000000       4.000000       5.000000
# Bathrooms        2.000000       3.000000       3.000000
# YearBuilt     1985.000000    2003.000000    2021.000000
# Price       225052.141166  279373.630052  492195.259972

# %%
v.tail()
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218

# %%
v.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %%
v['Neighborhood']
# Out:
# 0         Rural
# 1         Rural
# 2        Suburb
# 3         Urban
# 4        Suburb
#           ...
# 49995     Rural
# 49996    Suburb
# 49997    Suburb
# 49998     Rural
# 49999     Rural
# Name: Neighborhood, Length: 50000, dtype: str

# %%
v['YearBuilt']
# Out:
# 0        1969
# 1        1980
# 2        1970
# 3        1996
# 4        2001
#          ...
# 49995    1975
# 49996    1988
# 49997    1962
# 49998    1984
# 49999    2011
# Name: YearBuilt, Length: 50000, dtype: int64

# %%
v['Neighborhood','YearBuilt']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: ('Neighborhood', 'YearBuilt')
#
# ...

# %%
df[['Neighborhood','YearBuilt']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df[['Neighborhood','YearBuilt']]
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...

# %%
v[['Neighborhood','YearBuilt']]
# Out:
#       Neighborhood  YearBuilt
# 0            Rural       1969
# 1            Rural       1980
# 2           Suburb       1970
# 3            Urban       1996
# 4           Suburb       2001
# ...            ...        ...
# 49995        Rural       1975
# 49996       Suburb       1988
# 49997       Suburb       1962
# 49998        Rural       1984
# 49999        Rural       2011
#
# [50000 rows x 2 columns]

# %%
df[['Neighborhood','YearBuilt']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df[['Neighborhood','YearBuilt']].head()
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...

# %%
v[['Neighborhood','YearBuilt']].head()
# Out:
#   Neighborhood  YearBuilt
# 0        Rural       1969
# 1        Rural       1980
# 2       Suburb       1970
# 3        Urban       1996
# 4       Suburb       2001

# %%
v[['Neighborhood','YearBuilt']].head(3)
# Out:
#   Neighborhood  YearBuilt
# 0        Rural       1969
# 1        Rural       1980
# 2       Suburb       1970

# %%
v[['Neighborhood','YearBuilt']]	.loc

# %%
v[0:3:]
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076

# %%
v.loc[0:3,:]
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153

# %%
v.loc[0:8, 'SquareFeet']
# Out:
# 0    2126
# 1    2459
# 2    1860
# 3    2294
# 4    2130
# 5    2095
# 6    2724
# 7    2044
# 8    2638
# Name: SquareFeet, dtype: int64

# %%
v.loc[0:8,2:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 v.loc[0:8,2:3]
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\indexing.py:1395, in _LocIndexer._getitem_tuple(self, tup)
#    1392 if self._multi_take_opportunity(tup):
#    1393     return self._multi_take(tup)
# -> 1395 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
v.iloc[0:8,2:3]
# Out:
#    Bathrooms
# 0          1
# 1          2
# 2          1
# 3          1
# 4          2
# 5          3
# 6          1
# 7          3

# %%
v.iloc[0:8,'Bathrooms']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\indexing.py:993, in _LocationIndexer._validate_tuple_indexer(self, key)
#     992 try:
# --> 993     self._validate_key(k, i)
#     994 except ValueError as err:
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\indexing.py:1635, in _iLocIndexer._validate_key(self, key, axis)
#    1634 else:
# -> 1635     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
v.iloc[0:3,2:6]
# Out:
#    Bathrooms Neighborhood  YearBuilt          Price
# 0          1        Rural       1969  215355.283618
# 1          2        Rural       1980  195014.221626
# 2          1       Suburb       1970  306891.012076

# %%
v[v['price']>22000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
v[v['Price']>22000]
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [49918 rows x 6 columns]

# %%
v.query['Price']>22000']
# Out:
#   Cell In[45], line 1
#     v.query['Price']>22000']
#                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
v.query('Price'>22000']
# Out:
#   Cell In[46], line 1
#     v.query('Price'>22000']
#                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
v.query('Price'>22000')
# Out:
#   Cell In[47], line 1
#     v.query('Price'>22000')
#                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
  v.query('Price>22000')
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [49918 rows x 6 columns]

# %%
v.groupby('Neighbourhood')['YearBuilt']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 v.groupby('Neighbourhood')['YearBuilt']
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\frame.py:10821, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10817
#   10818         if level is None and by is None:
# ...

# %%
v.groupby('Neighborhood')['YearBuilt']

# %%
h=v.groupby('Neighbourhood')['YearBuilt']
h
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 h=v.groupby('Neighbourhood')['YearBuilt']
#       2 h
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\frame.py:10821, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10817
#   10818         if level is None and by is None:
# ...

# %%
v.groupby('Neighbourhood')['YearBuilt']

# %%
h=v.groupby('Neighborhood')['YearBuilt']
h

# %%
pricebyneighbourhood=v.groupby('Neighborhood')['YearBuilt']
pricebyneighbourhood

# %%
pricebyneighbourhood=v.groupby('Neighborhood')['YearBuilt']
pricebyneighbourhood()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 pricebyneighbourhood=v.groupby('Neighborhood')['YearBuilt']
# ----> 2 pricebyneighbourhood()
#
# TypeError: 'SeriesGroupBy' object is not callable

# %%
pricebyneighbourhood=v.groupby('Neighborhood')['YearBuilt']
pricebyneighbourhood

# %%
dc=v.groupby('Neighborhood')['Price']
pd.DataFrame(dc)
# Out:
#         0                                                  1
# 0   Rural  0        215355.283618
# 1        195014.221626
# ...
# 1  Suburb  2        306891.012076
# 4        272436.239065
# ...
# 2   Urban  3        206786.787153
# 8        377998.588152
# ...

# %%
v['Neighborhood'].value_counts()
# Out:
# Neighborhood
# Suburb    16721
# Rural     16676
# Urban     16603
# Name: count, dtype: int64

# %%
dc=v.groupby(['Neighborhood','Price'])
pd.DataFrame(dc)
# Out:
#                                   0  \
# 0       (Rural, -28774.99802220965)
# 1      (Rural, -19871.251145635964)
# 2      (Rural, -18159.685676249966)
# 3       (Rural, -13803.68405898445)
# 4       (Rural, -8238.884498829517)
# ...                             ...
# 49995    (Urban, 467492.8278233021)
# 49996    (Urban, 468470.3780038055)
# 49997    (Urban, 468493.8778409183)
# 49998    (Urban, 470989.6790739138)
# 49999    (Urban, 476671.7332626706)
#
#                                                        1
# 0             SquareFeet  Bedrooms  Bathrooms Neighbo...
# 1            SquareFeet  Bedrooms  Bathrooms Neighbor...
# 2             SquareFeet  Bedrooms  Bathrooms Neighbo...
# 3            SquareFeet  Bedrooms  Bathrooms Neighbor...
# 4             SquareFeet  Bedrooms  Bathrooms Neighbo...
# ...                                                  ...
# 49995         SquareFeet  Bedrooms  Bathrooms Neighbo...
# 49996         SquareFeet  Bedrooms  Bathrooms Neighbo...
# ...
