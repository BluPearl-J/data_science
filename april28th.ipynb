# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.62.1-cp314-cp314-win_amd64.whl.metadata (119 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pillow-12.2.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
# ...

# %%
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot([1, 2, 3], [4, 5, 6])
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# %pip install matplotlib

# %%
x=[5,2,9,4,7]
y=[10,5,8,4,2]
plt.plot(x,y)
plt.show()
# Out:
# --------------------------------------------------------------------
# NameError                          Traceback (most recent call last)
# Cell In[1], line 3
#       1 x=[5,2,9,4,7]
#       2 y=[10,5,8,4,2]
# ----> 3 plt.plot(x,y)
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Sales")  
#right plot
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("Shopping")
plt.suptitle("Store Data 2026") #main title for both
plt.tight_layout() #preventd title from overlapping
plt.show()
