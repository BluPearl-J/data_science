# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pit

# %%
1.what is average house price
2.minimum maximum price
3.total houses in dataset
5.average square footage
6.common number of bedrooms
7.common number of bathrooms
8.how many houses in each neighbourhood
9average price per neighbourhood 
9oldest hpuse(yesr built
10 newesthouse
11average price of houses with 3 bedrooms
12 how many houses have more than 4 bedrooms
213 average square footage of urban houses
14 median price
15 price distributon
16 percentage of house in suburban areas
17 average number of bathrooms
18 how many houses were built after 2000
# Out:
#   Cell In[20], line 1
#     1.what is average house price
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# QUESTION 1 ANSWER average house price is224827.325151
#
# ANSWER QUESTION 2.total houses in dataset =50 000 houses
#
# answer question 9: OLDEST HOUSE =v.describe()
# min//oldest house was built in 1950
#
# squareFeet   bBedrooms  Bathroooms   YearBuilt
# 1000.000000	2.000000	1.000000	1950.000000
#
# answer question 10: NEWEST HOUSE =v.describe()
# MAX//NEWEST HOUSE has
# squarefoot   Bedrooms   Bathrooms    YearBuilt   Price
# 2999.000000	5.000000	3.000000	2021.000000	492195.259972
#
# answer queston 7
# Neighborhood
# Suburb    16721
# Rural     16676
# Urban     16603
# Name: count, dtype: int64
#
# answer question 11
# 11average price of houses with 3 bedrooms 12 661 divide 50000
# =0.25322*100=325.322%
#
#
# 12 how many houses have more than 4 bedrooms
# answer 5 12 468
#
#
#
# answer question 16;
# 16 percentage of house in suburban areas
# =33.442% answer
#
# answer question 17
# 1.995420	mean number of bathrooms
#
# ANSWER QUESTION 18. 14,404 HOUSES WERE BUILT AFTER THE YEAR 2000
#
# answered 10

# %%
v=pd.read_csv(r'\Users\DELL\Downloads\archive\housing_price_dataset.csv')
v
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %% [markdown]
# 1.what is average house price
# 2.minimum maximum price
# 3.total houses in dataset
# 4.average square footage
# 5.most common number of bedrooms
# 6.most common number of bathrooms
#
# 7.how many houses in each neighbourhood
# 8average price per neighbourhood
# 9oldest hpuse(year built
#
# 10 newesthouse
# 11average price of houses with 3 bedrooms
# 12 how many houses have more than 4 bedrooms
# 213 average square footage of urban houses
# 14 median price
# 15 price distributon
# 16 percentage of house in suburban areas
# 17 average number of bathrooms
# 18 how many houses were built after 2000
# 19average price of rural houses
# 20 difference between urban and rural prices
# pip install matplotlib

# %% [markdown]
# v.describe()

# %% [markdown]
# 1. what isaverage house price

# %% [markdown]
# average house price is224827.325151

# %%
2.total houses in dataset =50 000 houses

# %%
v.tail()
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218

# %%
v.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %%
v[v['Price']>22000]
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [49918 rows x 6 columns]

# %% [markdown]
#     QUESTION 18 HOW MANY HOUSES BUILT AFTER 2000

# %%
v[v['YearBuilt']>22000]
# Out:
# Empty DataFrame
# Columns: [SquareFeet, Bedrooms, Bathrooms, Neighborhood, YearBuilt, Price]
# Index: []

# %%
v[v['YearBuilt']>2000]
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 4            2130         5          2       Suburb       2001  272436.239065
# 5            2095         2          3       Suburb       2020  198208.803907
# 9            1121         5          2        Urban       2004   95961.926014
# 23           1343         2          3        Rural       2013  151733.922490
# 24           2515         2          3        Urban       2013  307961.107382
# ...           ...       ...        ...          ...        ...            ...
# 49981        1564         4          3        Rural       2019  225878.769455
# 49982        2280         5          3       Suburb       2009  258515.417621
# 49987        2237         4          1        Rural       2011  227359.621341
# 49993        1215         2          3        Urban       2017  126052.390562
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [14404 rows x 6 columns]

# %% [markdown]
# ANSWER QUESTION 18.
# 14,404 HOUSES WERE BUILT AFTER THE YEAR 2000

# %%
  v.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325151
# std      575.513241      1.116326      0.815851     20.719377   76141.842966
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.165397
# 25%     1513.000000      3.000000      1.000000   1967.000000  169955.860225
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.141166
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.630052
# max     2999.000000      5.000000      3.000000   2021.000000  492195.259972

# %%
v['Neighborhood'].value_counts()
# Out:
# Neighborhood
# Suburb    16721
# Rural     16676
# Urban     16603
# Name: count, dtype: int64

# %% [markdown]
# 16 percentage of house in suburban areas= 16721 divide (16721+16676+16603) *100 =
# 16721 divide 50000 =0.33442*100
# =33.442% answer

# %%
1.995420	mean number of bathrooms

# %%
v['Bathrooms'].value_counts()
# Out:
# Bathrooms
# 1    16755
# 2    16719
# 3    16526
# Name: count, dtype: int64

# %%
11average price of houses with 3 bedrooms 16 526 divide 50000
=0.33052*100=33.052%

12 how many houses have more than 4 bedrooms

# %%
v['Bathrooms'].value_counts()
# Out:
# Bathrooms
# 1    16755
# 2    16719
# 3    16526
# Name: count, dtype: int64

# %%
v['Bedrooms'].value_counts()
# Out:
# Bedrooms
# 3    12661
# 5    12468
# 2    12436
# 4    12435
# Name: count, dtype: int64

# %% [markdown]
# 11average price of houses with 3 bedrooms 12 661 divide 50000
# =0.25322*100=325.322%
#
# 12 how many houses have more than 4 bedrooms
# answer 5 12 468

# %%
pip install matplot
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 570.0 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/8.3 MB 720.7 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/8.3 MB 720.7 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.0/8.3 MB 674.9 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.0/8.3 MB 674.9 kB/s eta 0:00:11
#    ------ --------------------------------- 1.3/8.3 MB 637.2 kB/s eta 0:00:11
#    ------ --------------------------------- 1.3/8.3 MB 637.2 kB/s eta 0:00:11
#    ------- -------------------------------- 1.6/8.3 MB 629.3 kB/s eta 0:00:11
# ...

# %%
v.query("Bedroooms==3")['Price'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\core\computation\scope.py:232, in Scope.resolve(self, key, is_local)
#     231 if self.has_resolvers:
# --> 232     return self.resolvers[key]
#     234 # if we're here that means that we have no locals and we also have
#     235 # no resolvers
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\collections\__init__.py:1025, in ChainMap.__getitem__(self, key)
#    1024         pass
# -> 1025 return self.__missing__(key)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\collections\__init__.py:1017, in ChainMap.__missing__(self, key)
#    1016 def __missing__(self, key):
# -> 1017     raise KeyError(key)
#
# KeyError: 'Bedroooms'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
hf=v.groupby("Neighborhood")["Price"].mean()
hf
# Out:
# Neighborhood
# Rural     224096.126040
# Suburb    223234.189857
# Urban     227166.197139
# Name: Price, dtype: float64

# %%
v.query("Bedrooms==3"){"price"}.mean

# %% [markdown]
# hf=v.groupby("N
# GROUP BY DONT TAKE CONDITIONS USE QUERY

# %%
v.query("Bedrooms==3"

# %%
v["Price"].hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 v["Price"].hist()
#
# File ~\OneDrive\Desktop\MrEvansDataAnalysisClass\analysis-env\Lib\site-packages\pandas\plotting\_core.py:131, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      49 @set_module("pandas.plotting")
#      50 def hist_series(
#      51     self: Series,
#    (...)     63     **kwargs,
#      64 ):
#      65     """
#      66     Draw histogram of the input series using matplotlib.
#      67
#    (...)    129         >>> hist = ser.groupby(level=0).hist()
#     130     """
# --> 131     plot_backend = _get_plot_backend(backend)
#     132     return plot_backend.hist_series(
#     133         self,
#     134         by=by,
#    (...)    144         **kwargs,
#     145     )
#
# ...

# %%
hf=v.query("Neighborhood=='Suburb'").value_counts().sum()
total_count=v["Neighborhood"].value_counts().sum()
result=
(suburb_count divide total_count)*100




v.query('Neighborhood=="Rural"')["Price"].mean()
# Out:
#   Cell In[27], line 3
#     result=
#            ^
# SyntaxError: invalid syntax

# %%
urban_price=v.query("Neighborhood=='urban'")["Price].mean()
rural=v.query("Neighborhood=='Rural'")["Price].mean()
difference=urban_price-rural
difference
# Out:
#   Cell In[29], line 1
#     urban_price=v.query("Neighborhood=='urban'")["Price].mean()
#                                                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
differebce=
.(df
.groupby("Neighborhood")["Price"].mean()
.loc["Urban","Rural"]]
  //.loc gores into neighborhood extraxctsurban and rural two columns
.diff()
)
difference
# Out:
#   Cell In[30], line 4
#     .loc["Urban","Rural"]]
#                          ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '(' on line 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pit

v=pd.read_csv(r'\Users\DELL\Downloads\archive\housing_price_dataset.csv')
v
v["Price"].hist()
# Out:
# <Axes: >
